# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p))

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

n, p = 50, 0.5
x = np.arange(0,50,0.001)
plt.plot(x,binom.pmf(x, n, p))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
n, p = 10, 0.167
x = np.arange(0,10,0.001)
plt.plot(x,binom.pmf(x, n, p))

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom
n, p = 16, 0.167
x = np.arange(0,16,0.001)
plt.plot(x,binom.pmf(x, n, p))

# %%
#poisson cummulative mass fun
poisson.cdf(4,8)
# Out:
# 0.09963240048704596

# %%
# for no probabilty
poisson.pmf(0,8/12)
# Out:
# 0.513417119032592

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-e3372ed187c5> in <module>
#       4
#       5 # Create the sample
# ----> 6 sample = poisson.___(mu=8, size=10000, random_state=13)
#       7
#       8 # Plot the sample
#
# AttributeError: 'poisson_gen' object has no attribute '___'
